# %% [markdown]
# # Relatório de Análise 1

# %% [markdown]
# ## Importando a base de dados

# %%
import pandas as pd

# %%
pd.read_csv('dados/aluguel.csv', sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados = pd.read_csv('dados/aluguel.csv', sep=';')

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
# Sem especificar parâmetro, a função retorna as 5 primeiras linhas do dataframe
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
# Podemos solicitar uma quantidade de dados determinada, passando o valor como parâmetro.
dados.head(15)
# Out:
#                        Tipo               Bairro  Quartos  Vagas  Suites  \
# 0                 Quitinete           Copacabana        1      0       0
# 1                      Casa      Jardim Botânico        2      0       1
# 2   Conjunto Comercial/Sala      Barra da Tijuca        0      4       0
# 3               Apartamento               Centro        1      0       0
# 4               Apartamento         Higienópolis        1      0       0
# 5               Apartamento         Vista Alegre        3      1       0
# 6               Apartamento             Cachambi        2      0       0
# 7        Casa de Condomínio      Barra da Tijuca        5      4       5
# 8        Casa de Condomínio                Ramos        2      2       0
# 9   Conjunto Comercial/Sala               Centro        0      3       0
# 10              Apartamento               Centro        1      0       0
# 11              Apartamento               Grajaú        2      1       0
# ...

# %%
# Sem especificar parâmetro, a função retorna as 5 primeiras últimas linhas do dataframe.
dados.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
dados.tail(10)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %% [markdown]
# ## Informações gerais sobre a Base de Dados

# %%
# A descrição "object" no Pandas é uma string
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
# Exibindo o dtypes com uma melhor formatação, como um dataframe
pd.DataFrame(dados.dtypes, columns=['Tipos de dados'])
# Out:
#            Tipos de dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
# Nomeando a coluna com os tipos de dados
tipos_de_dados = pd.DataFrame(dados.dtypes, columns=['Tipos de dados'])

# %%
# Nomeando a coluna com a lista das variáveis do DataFrame
tipos_de_dados.columns.name = 'Variáveis'
tipos_de_dados
# Out:
# Variáveis  Tipos de dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Retornando o número de registros e o número de variáveis (colunas) no DataFrame
dados.shape
# Out:
# (32960, 9)

# %%
# Lendo o primeiro item da tupla
dados.shape[0]
# Out:
# 32960

# %%
print(f'A base de dados apresenta {dados.shape[0]} registros (imóveis) e {dados.shape[1]} variáveis.')
# Out:
# A base de dados apresenta 32960 registros (imóveis) e 9 variáveis.

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## 01 - Informações de um DataFrame
# Considere o seguinte código Python no Jupyter:

# %%
import pandas as pd
data = [['Fulano', 12, 7.0, True],
        ['Sicrano', 15, 3.5, False],
        ['Beltrano', 18, 9.3, True]]
dados_alunos = pd.DataFrame(data,
        columns = ['Aluno', 'Idade', 'Nota', 'Aprovado'])
dados_alunos
# Out:
#       Aluno  Idade  Nota  Aprovado
# 0    Fulano     12   7.0      True
# 1   Sicrano     15   3.5     False
# 2  Beltrano     18   9.3      True

# %% [markdown]
# Executando este código, obtemos o DataFrame abaixo:
# ```
# 	Aluno	Idade	Nota	Aprovado
# 0	Fulano	12	7.0	True
# 1	Sicrano	15	3.5	False
# 2	Beltrano	18	9.3	True
# ```
#
# Para obtermos uma tabela contendo os nomes das variáveis e seus respectivos tipos de dados, conforme o exemplo abaixo, que linhas de código devemos executar no Jupyter?
# ```
# Variáveis	Tipos de Dados
# Aluno	object
# Idade	int64
# Nota	float64
# Aprovado	bool
# ```

# %%
# Resposta do exercício 01
tipos_de_dados_alunos = pd.DataFrame(dados_alunos.dtypes,
    columns = ['Tipos de Dados'])
tipos_de_dados_alunos.columns.name = 'Variáveis'
tipos_de_dados_alunos
# Out:
# Variáveis Tipos de Dados
# Aluno             object
# Idade              int64
# Nota             float64
# Aprovado            bool

# %% [markdown]
# ## Fim
