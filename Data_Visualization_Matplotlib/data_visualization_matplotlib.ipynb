# %% [markdown]
# # Curso: Data Visualization com Matplotlib

# %% [markdown]
# ## Aula 1

# %% [markdown]
# ### Fazendo as primeiras vizualizações

# %%
import pandas as pd

# %%
df = pd.read_csv('monitoramento_tempo.csv')

# %%
df.head()
# Out:
#    temperatura  pressão  ...  dia_da_semana                 data
# 0   282.080000   1024.0  ...        Domingo  2012-10-01 12:00:00
# 1   282.080000   1024.0  ...        Domingo  2012-10-01 13:00:00
# 2   282.083252   1024.0  ...        Domingo  2012-10-01 14:00:00
# 3   282.091866   1024.0  ...        Domingo  2012-10-01 15:00:00
# 4   282.100481   1024.0  ...        Domingo  2012-10-01 16:00:00
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %% [markdown]
# Convertendo o tipo da coluna data, de object (string) para datetime:

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

# Caso esteja no Jupyter Notebook. Assim os gráficos
# aparecem automaticamente

# %%
plt.plot(df['data'], df['temperatura'])

# %% [markdown]
# Obs: Como o nosso caso hipotético se trata de uma estação meteorológica, provavelmente os dados de temperatura foram salvos em Kelvin

# %%
# Alterando o tamanho do nosso gráfico
plt.figure(figsize=(15,8))

plt.plot(df['data'], df['temperatura'])

# %%
# Adicionando um título ao nosso gráfico
plt.figure(figsize=(15,8))
plt.plot(df['data'], df['temperatura'])
plt.title('Temperatura no tempo')
# Out:
# Text(0.5, 1.0, 'Temperatura no tempo')

# %% [markdown]
# ### Criando visualizações mais robustas

# %% [markdown]
# Criaremos uma variável eixo recebendo a função fig.add_axes(), que nos permitirá adicionar os eixos x e y a nossa figura. Ela receberá como argumento uma lista contendo os pontos em que esse eixo será desenhado, nesse caso 0, 0, 1, 1.

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])

# %%
# Plotando e adicionando um título novamente ao gráfico
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no momento')
# Out:
# Text(0.5, 1.0, 'Temperatura no momento')

# %%
# Adicionando rótulos aos eixos x e y
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no momento')
eixo.set_ylabel('Temperatura')
eixo.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
# Aumentando o tamanho da fonte
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
# Out:
# Text(0.5, 0, 'Data')

# %%
# Adicionando uma legenda
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)

# %%
# Alterando a cor do gráfico
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color = 'lime')

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)

# %% [markdown]
# ## Aula 2

# %% [markdown]
# ## Customizando nossas visualizações

# %%
# lw é o parâmetro que significa espessura de linha
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color = 'orange', lw = 4)

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color = 'orange', lw = 0.5)

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)

# %%
# ls é a abreviação de line style
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color = 'green', ls = "dotted")

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)

# %%
import datetime

# %%
# Limitando o período do eixo x, com o xlim()
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color = 'green')

eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)

# %%
# Adicionando marcadores à nossa visualização
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color = 'green', marker = 'o')

eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)

# %%
# Adicionando linhas de grade ao nosso gráfico
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color = 'green')

eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=15)
eixo.grid(True)

# %% [markdown]
# ### Mais de um eixo na mesma visualização
#
# Agora que já conseguimos fazer uma visualização legal, pra melhorar, podemos fazer uma visualização dentro de outra visualização, na mesma figura, como por exemplo uma visualização com foco no ano de 2014 e em um dos cantos da figura toda a série histórica.

# %%
# Gerando os nossos eixos
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

# %%
# OBS: 
# O pad vai dar uma distância do título para o gráfico
# O loc='best' faz com que automaticamente a legenda seja posicionada da forma 
# que a nossa biblioteca considerar melhor
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='best', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'violet')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='best', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df['data'], df['temperatura'], color = 'blue', lw = 0.3)
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %%
# Alterando a posição do gráfico menor

# a localização da legenda pode ser upper ou lower

fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'violet')
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura em 2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='upper left', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'blue', lw = 0.3)
eixo2.set_title('Temperatura de 2013 a 2018', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ### Uma visualização mais complexa

# %%
# Alterando a faixa temporal de cobertura dos gráficos
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'violet')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_title('Temperatura em maio de 2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='upper left', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'blue')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %%
# Reposicionando o gráfico da variável eixo
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'green')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura em maio/2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='upper left', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'blue')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %%
# Destacando o mês de maio no gráfico menor
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'green', lw = 3)
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura em maio/2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='upper left', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

azul_esquerda = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df['data'] > datetime.datetime(2014,6,1)


eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'green', lw = 0.8)
eixo2.plot(df[azul_esquerda]['data'],df[azul_esquerda]['temperatura'], color = 'blue')
eixo2.plot(df[azul_direita]['data'],df[azul_direita]['temperatura'], color = 'blue')

eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.legend(['Temperatura'], loc='upper left', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ## Aula 3

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

# Definindo o posicionamento da anotação
x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

x01 = df['data'][df['temperatura'].idxmin()]
y01 = min(df['temperatura'])

# Inserindo anotação
eixo.annotate("Máximo", xy=(x1,y1), fontsize=20)

eixo.annotate("Mínimo", xy=(x01,y01), fontsize=20)

# Inserindo as barras delimitadoras
eixo.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %%
# Reposicionando a anotação e melhorando a visibilidade
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

# Definindo o posicionamento da anotação 'Máximo'
x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

# reposicionando a anotação
x2 = df['data'][df['temperatura'].idxmax() - 7000]  # 7000 se refere a horas
y2 = max(df['temperatura']) - 5

# Inserindo anotação
eixo.annotate("Máximo", xy=(x1,y1), fontsize=20, 
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

# Definindo o posicionamento da anotação 'Mínimo'
x1 = df['data'][df['temperatura'].idxmin()]
y1 = min(df['temperatura'])

# reposicionando a anotação
x2 = df['data'][df['temperatura'].idxmin() - 7000]  # 7000 se refere a horas
y2 = min(df['temperatura']) + 5

# Inserindo anotação
eixo.annotate("Mínimo", xy=(x01,y01), fontsize=20, 
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

# Inserindo as barras delimitadoras
eixo.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %% [markdown]
# ### Criando um gráfico de barras

# %%
temperatura_por_dia_da_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'red', 'green', 'blue', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
# Inserindo cor de borda no gráfico de barras 
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'red', 'green', 'blue', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores, edgecolor='black')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %% [markdown]
# ### Criando um gráfico de pizza

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct='%.1f%%')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
# Enfatizando alguns dias da semana
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.1, 0, 0, 0, 0, 0.1, 0.1]

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct='%.1f%%', explode=explodir, shadow=True)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %% [markdown]
# ## Aula 4

# %% [markdown]
# ### Utilizando gráficos de dispersão

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    comprimento_sépala  largura_sépala  ...  largura_pétala      espécie
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)

# %%
# 
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'red', 'Iris-versicolor': 'blue', 'Iris-virginica': 'green'}
marcadores = {'Iris-setosa': 'x', 'Iris-versicolor': 'o', 'Iris-virginica': 'v'}

for especie in df['espécie'].unique():
  tmp = df[df['espécie'] == especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
               color=cores[especie], marker=marcadores[especie],
               s=100)

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20)

# %% [markdown]
# ### Utilizando gráfico de caixa

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df['largura_pétala'])
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(['largura_pétala'])
# Out:
# [Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
  caixa.set(color=cor)

for outlier in caixas['fliers']:
  outlier.set(marker='x', markersize=8)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'])
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df['comprimento_pétala'], orientation='horizontal')
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala')
eixo.grid(True)

# %%
# Calculando a média e o desvio-padrão
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df['comprimento_pétala'], bins=20, density=True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala')
eixo.grid(True)

# %%
# Calculando a média e o desvio-padrão
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df['comprimento_pétala'], bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala')
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
              xy=(4.5, 20), fontsize=14)
# Out:
# Text(4.5, 20, '$mu = 3.76$\n$sigma = 1.76$')

# %%
# Indicando posição da média e da mediana no gráfico
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

# calculando a média e o desvio-padrão
mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df['comprimento_pétala'], bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala')
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy=(4.5, 20), fontsize=14)

# desenhando correspondente à média
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-1.3, 28), fontsize=14)

# desenhando reta correspondente à mediana
eixo.axvline(df['comprimento_pétala'].median(), color='green', linestyle='--')
eixo.annotate('mediana', xy=(df['comprimento_pétala'].median(), 31), fontsize=14)
# Out:
# Text(4.35, 31, 'mediana')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris.csv')

# %%
# Criando histograma da Iris Versicolor

# Exibir nas distribuições o comprimento de pétala de todas as espécies
# Indicando posição da média e da mediana no gráfico
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

#iris versicolor
df_iv = df[df['espécie'] == 'Iris-versicolor'] 

# calculando a média e o desvio-padrão
mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df_iv['comprimento_pétala'], bins=20)
eixo.set_title('Iris Versicolor', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=12)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy=(4.6, 6), fontsize=14)

# desenhando reta correspondente à média
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-0.5, 5.5), fontsize=14)

# desenhando reta correspondente à mediana
eixo.axvline(df_iv['comprimento_pétala'].median(), color='green', linestyle='--')
eixo.annotate('mediana', xy=(df_iv['comprimento_pétala'].median()-0.7, 6.5), 
              color='green', fontsize=14)

# salvando a imagem do gráfico
fig.savefig('histograma_iv.png', bbox_inches='tight')

# %%
# Criando histograma da Iris Versicolor

# Exibir nas distribuições o comprimento de pétala de todas as espécies
# Indicando posição da média e da mediana no gráfico
fig = plt.figure(figsize=(7,6))
eixo = fig.add_axes([0,0,1,1])

#iris versicolor
df_iv = df[df['espécie'] == 'Iris-versicolor'] 

# calculando a média e o desvio-padrão
mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df_iv['comprimento_pétala'], bins=20)
eixo.set_title('Iris Versicolor', fontsize=17, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=12)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy=(4.6, 6), fontsize=15)

# desenhando reta correspondente à média
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-0.3, 5.5), fontsize=14)

# desenhando reta correspondente à mediana
eixo.axvline(df_iv['comprimento_pétala'].median(), color='green', linestyle='--')
eixo.annotate('mediana', xy=(df_iv['comprimento_pétala'].median()-0.45, 
                             6.5), color='green', fontsize=14)

# salvando a imagem do gráfico
fig.savefig('histograma_iv_0.png', bbox_inches='tight')

# %%
# Criando histograma da Iris Setosa

# Exibir nas distribuições o comprimento de pétala de todas as espécies
# Indicando posição da média e da mediana no gráfico
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

#iris versicolor
df_is = df[df['espécie'] == 'Iris-setosa'] 

# calculando a média e o desvio-padrão
mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df_is['comprimento_pétala'], bins=20)
eixo.set_title('Iris Setosa', fontsize=17, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=12)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy=(1.7, 7), fontsize=15)

# desenhando reta correspondente à média
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-0.2, 13.5), fontsize=14)

# desenhando reta correspondente à mediana
eixo.axvline(df_is['comprimento_pétala'].median(), color='green', linestyle='--')
eixo.annotate('mediana', xy=(df_is['comprimento_pétala'].median()+0.05, 
                             12), color='green',fontsize=14)

# salvando a imagem do gráfico
fig.savefig('histograma_is.png', bbox_inches='tight')

# %%
# Criando histograma da Iris Virginica

# Exibir nas distribuições o comprimento de pétala de todas as espécies
# Indicando posição da média e da mediana no gráfico
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

#iris versicolor
df_ivg = df[df['espécie'] == 'Iris-virginica'] 

# calculando a média e o desvio-padrão
mu, sigma = df_ivg['comprimento_pétala'].mean(), df_ivg['comprimento_pétala'].std()

# bins define o número de colunas (interfere na riqueza de detalhes)
eixo.hist(df_ivg['comprimento_pétala'], bins=20)
eixo.set_title('Iris Virginica', fontsize=17, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=12)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy=(6.3, 7), fontsize=15)

# desenhando reta correspondente à média
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu, 8), fontsize=14)

# desenhando reta correspondente à mediana
eixo.axvline(df_ivg['comprimento_pétala'].median(), color='green', linestyle='--')
eixo.annotate('mediana', xy=(df_ivg['comprimento_pétala'].median(), 
                             7), color='green',fontsize=14)

# salvando a imagem do gráfico
fig.savefig('histograma_ivg.png', bbox_inches='tight')

# %%
from PIL import Image

largura, altura = Image.open('histograma_ivg.png').size
combinada = Image.new("RGB", (3*largura, altura))
intervalo = 0

for imagem in map(Image.open, ['histograma_iv.png', 'histograma_is.png', 
                               'histograma_ivg.png']):
  combinada.paste(imagem, (intervalo, 0))  # intervalo e 0 correspondem aos eixos x e y
  intervalo += largura

combinada.save('combinada.png')

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1176x360 at 0x7FF826D229D0>

# %% [markdown]
# ## Linhas e Marcadores

# %% [markdown]
# Documentação: https://matplotlib.org/3.1.3/api/markers_api.html
#
# >':' = linha pontilhada -> ........................
#
# >'-.' = traço e ponto no mesmo nível
#
# >'--' = tracejada -> ------------------------------
#
# >'-' = linha reta

# %% [markdown]
# ## **Cores no Matplotlib (Documentação)**
#
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, title, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12
    topmargin = 40

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + margin + topmargin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-topmargin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()
    ax.set_title(title, fontsize=24, loc="left", pad=10)

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

plot_colortable(mcolors.BASE_COLORS, "Base Colors",
                sort_colors=False, emptycols=1)
plot_colortable(mcolors.TABLEAU_COLORS, "Tableau Palette",
                sort_colors=False, emptycols=2)

plot_colortable(mcolors.CSS4_COLORS, "CSS Colors")

# Optionally plot the XKCD colors (Caution: will produce large figure)
#xkcd_fig = plot_colortable(mcolors.XKCD_COLORS, "XKCD Colors")
#xkcd_fig.savefig("XKCD_Colors.png")

plt.show()

# %% [markdown]
# ## **CONTEÚDO EXTRA: Cores nomeadas no Matplotlib**
#
# ### Nesta seção, os códigos para exibição das cores são de autoria de usuários do QA Stack e foram extraídos deste link:
# https://qastack.com.br/programming/22408237/named-colors-in-matplotlib
#
# https://xkcd.com/color/rgb/
#
# https://www.computerhope.com/htmcolor.htm
#
# Obs: esta seção não pertence ao conteúdo fornecido pela Alura

# %%
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors


colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

# Sort colors by hue, saturation, value and name.
by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                for name, color in colors.items())
sorted_names = [name for hsv, name in by_hsv]

n = len(sorted_names)
ncols = 4
nrows = n // ncols

fig, ax = plt.subplots(figsize=(12, 10))

# Get height and width
X, Y = fig.get_dpi() * fig.get_size_inches()
h = Y / (nrows + 1)
w = X / ncols

for i, name in enumerate(sorted_names):
    row = i % nrows
    col = i // nrows
    y = Y - (row * h) - h

    xi_line = w * (col + 0.05)
    xf_line = w * (col + 0.25)
    xi_text = w * (col + 0.3)

    ax.text(xi_text, y, name, fontsize=(h * 0.8),
            horizontalalignment='left',
            verticalalignment='center')

    ax.hlines(y + h * 0.1, xi_line, xf_line,
              color=colors[name], linewidth=(h * 0.8))

ax.set_xlim(0, X)
ax.set_ylim(0, Y)
ax.set_axis_off()

fig.subplots_adjust(left=0, right=1,
                    top=1, bottom=0,
                    hspace=0, wspace=0)
plt.show()

# %%
# Exemplo externo ao curso, de como aplicar o código xkcd
# Fonte: QA Stack
plt.plot([1,2], lw=4, c='xkcd:baby poop green')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors
import math


fig = plt.figure(figsize=(14, 12))
ax = fig.add_subplot(111)

ratio = 1.0 / 3.0
count = math.ceil(math.sqrt(len(colors.cnames)))
x_count = count * ratio
y_count = count / ratio
x = 0
y = 0
w = 1 / x_count
h = 1 / y_count

for c in colors.cnames:
    pos = (x / x_count, y / y_count)
    ax.add_patch(patches.Rectangle(pos, w, h, color=c))
    ax.annotate(c, xy=pos)
    if y >= y_count-1:
        x += 1
        y = 0
    else:
        y += 1

plt.show()

# %%
# Lista com nomes das cores e código
import matplotlib
for name, hex in matplotlib.colors.cnames.items():
    print(name, hex)
# Out:
# aliceblue #F0F8FF
# antiquewhite #FAEBD7
# aqua #00FFFF
# aquamarine #7FFFD4
# azure #F0FFFF
# beige #F5F5DC
# bisque #FFE4C4
# black #000000
# blanchedalmond #FFEBCD
# blue #0000FF
# blueviolet #8A2BE2
# brown #A52A2A
# burlywood #DEB887
# cadetblue #5F9EA0
# chartreuse #7FFF00
# chocolate #D2691E
# coral #FF7F50
# cornflowerblue #6495ED
# cornsilk #FFF8DC
# crimson #DC143C
# cyan #00FFFF
# darkblue #00008B
# darkcyan #008B8B
# darkgoldenrod #B8860B
# darkgray #A9A9A9
# darkgreen #006400
# darkgrey #A9A9A9
# darkkhaki #BDB76B
# darkmagenta #8B008B
# darkolivegreen #556B2F
# darkorange #FF8C00
# darkorchid #9932CC
# darkred #8B0000
# darksalmon #E9967A
# darkseagreen #8FBC8F
# darkslateblue #483D8B
# darkslategray #2F4F4F
# darkslategrey #2F4F4F
# darkturquoise #00CED1
# darkviolet #9400D3
# deeppink #FF1493
# deepskyblue #00BFFF
# dimgray #696969
# dimgrey #696969
# dodgerblue #1E90FF
# firebrick #B22222
# floralwhite #FFFAF0
# forestgreen #228B22
# fuchsia #FF00FF
# gainsboro #DCDCDC
# ghostwhite #F8F8FF
# gold #FFD700
# goldenrod #DAA520
# gray #808080
# green #008000
# greenyellow #ADFF2F
# grey #808080
# honeydew #F0FFF0
# hotpink #FF69B4
# indianred #CD5C5C
# indigo #4B0082
# ivory #FFFFF0
# khaki #F0E68C
# lavender #E6E6FA
# lavenderblush #FFF0F5
# lawngreen #7CFC00
# lemonchiffon #FFFACD
# lightblue #ADD8E6
# lightcoral #F08080
# lightcyan #E0FFFF
# lightgoldenrodyellow #FAFAD2
# lightgray #D3D3D3
# lightgreen #90EE90
# lightgrey #D3D3D3
# lightpink #FFB6C1
# lightsalmon #FFA07A
# lightseagreen #20B2AA
# lightskyblue #87CEFA
# lightslategray #778899
# lightslategrey #778899
# lightsteelblue #B0C4DE
# lightyellow #FFFFE0
# lime #00FF00
# limegreen #32CD32
# linen #FAF0E6
# magenta #FF00FF
# maroon #800000
# mediumaquamarine #66CDAA
# mediumblue #0000CD
# mediumorchid #BA55D3
# mediumpurple #9370DB
# mediumseagreen #3CB371
# mediumslateblue #7B68EE
# mediumspringgreen #00FA9A
# mediumturquoise #48D1CC
# mediumvioletred #C71585
# midnightblue #191970
# mintcream #F5FFFA
# mistyrose #FFE4E1
# moccasin #FFE4B5
# navajowhite #FFDEAD
# navy #000080
# oldlace #FDF5E6
# olive #808000
# olivedrab #6B8E23
# orange #FFA500
# orangered #FF4500
# orchid #DA70D6
# palegoldenrod #EEE8AA
# palegreen #98FB98
# paleturquoise #AFEEEE
# palevioletred #DB7093
# papayawhip #FFEFD5
# peachpuff #FFDAB9
# peru #CD853F
# pink #FFC0CB
# plum #DDA0DD
# powderblue #B0E0E6
# purple #800080
# rebeccapurple #663399
# red #FF0000
# rosybrown #BC8F8F
# royalblue #4169E1
# saddlebrown #8B4513
# salmon #FA8072
# sandybrown #F4A460
# seagreen #2E8B57
# seashell #FFF5EE
# sienna #A0522D
# silver #C0C0C0
# skyblue #87CEEB
# slateblue #6A5ACD
# slategray #708090
# slategrey #708090
# snow #FFFAFA
# springgreen #00FF7F
# steelblue #4682B4
# tan #D2B48C
# teal #008080
# thistle #D8BFD8
# tomato #FF6347
# turquoise #40E0D0
# violet #EE82EE
# wheat #F5DEB3
# white #FFFFFF
# whitesmoke #F5F5F5
# yellow #FFFF00
# yellowgreen #9ACD32
