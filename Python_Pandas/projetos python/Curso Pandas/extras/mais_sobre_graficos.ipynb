# %% [markdown]
# # Mais sobre Gráficos

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

plt.rc('figure', figsize = (15, 8))

# %%
dados = pd.read_csv('dados/aluguel.csv', sep = ';')
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
area = plt.figure()

# %%
g1 = area.add_subplot(2, 2, 1)
g2 = area.add_subplot(2, 2, 2)
g3 = area.add_subplot(2, 2, 3)
g4 = area.add_subplot(2, 2, 4)

# %%
# Começando a fazer os nossos gráficos

# Criando um Gráfico de Dispersão
g1.scatter(dados.Valor, dados.Area)
g1.set_title('Valor X Área')

# Criando um Histograma
g2.hist(dados.Valor)
g2.set_title('Histograma')

# Amostra aleatória dentro do próprio DataFrame
dados_g3 = dados.Valor.sample(100)
#Temos que refazer o índice
dados_g3.index = range(dados_g3.shape[0])
g3.set_title('Amostra Valor')
g3.plot(dados_g3)

# Criando um gráfico de barra
grupo = dados.groupby('Tipo')['Valor']
label = grupo.mean().index
valores = grupo.mean().values
g4.set_title('Valor Médio por Tipo')
g4.bar(label, valores)
# Out:
# <BarContainer object of 5 artists>

# %%
area

# %%
area.savefig('grafico.png', dpi = 300, bbox_inches = 'tight')

# %% [markdown]
# OBS: O dpi define a resolução da imagem. O bbox_inches remove as bordas brancas da imagem.

# %% [markdown]
# ## Fim
